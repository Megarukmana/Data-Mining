# %% [markdown]
# # Tugas 2
# ## Pre Processing Data
# ### Cleaning Data

# %%
import pandas as pd
import numpy as np

# %%
weather = pd.read_csv("D:\statistika\SEMESTER 6\DATMIN\Pre Processing Data\weatherAUS_tugas2.csv", sep=';')

# %%
weather
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       01/12/2008   Albury     13.4     22.9       0.6          NaN
# 1       02/12/2008   Albury      7.4     25.1       0.0          NaN
# 2       03/12/2008   Albury     12.9     25.7       0.0          NaN
# 3       04/12/2008   Albury      9.2     28.0       0.0          NaN
# 4       05/12/2008   Albury     17.5     32.3       1.0          NaN
# 5       06/12/2008   Albury     14.6     29.7       0.2          NaN
# 6       07/12/2008   Albury     14.3     25.0       0.0          NaN
# 7       08/12/2008   Albury      7.7     26.7       0.0          NaN
# 8       09/12/2008   Albury      9.7     31.9       0.0          NaN
# 9       10/12/2008   Albury     13.1     30.1       1.4          NaN
# 10      11/12/2008   Albury     13.4     30.4       0.0          NaN
# 11      12/12/2008   Albury     15.9     21.7       2.2          NaN
# 12      13/12/2008   Albury     15.9     18.6      15.6          NaN
# ...

# %%
weather.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  01/12/2008   Albury     13.4     22.9       0.6          NaN       NaN
# 1  02/12/2008   Albury      7.4     25.1       0.0          NaN       NaN
# 2  03/12/2008   Albury     12.9     25.7       0.0          NaN       NaN
# 3  04/12/2008   Albury      9.2     28.0       0.0          NaN       NaN
# 4  05/12/2008   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0           W           44.0          W      ...             22.0
# 1         WNW           44.0        NNW      ...             25.0
# 2         WSW           46.0          W      ...             30.0
# 3          NE           24.0         SE      ...             16.0
# 4           W           41.0        ENE      ...             33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
weather.tail()
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 142188  20/06/2017    Uluru      3.5     21.8       0.0          NaN
# 142189  21/06/2017    Uluru      2.8     23.4       0.0          NaN
# 142190  22/06/2017    Uluru      3.6     25.3       0.0          NaN
# 142191  23/06/2017    Uluru      5.4     26.9       0.0          NaN
# 142192  24/06/2017    Uluru      7.8     27.0       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am      ...       \
# 142188       NaN           E           31.0        ESE      ...
# 142189       NaN           E           31.0         SE      ...
# 142190       NaN         NNW           22.0         SE      ...
# 142191       NaN           N           37.0         SE      ...
# 142192       NaN          SE           28.0        SSE      ...
#
#        Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 142188        27.0       1024.7       1021.2       NaN       NaN      9.4
# ...

# %%
weather.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  141556.000000  141871.000000  140787.000000  81350.000000
# mean       12.186400      23.226784       2.349974      5.469824
# std         6.403283       7.117618       8.465173      4.188537
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.800000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  74377.000000  132923.000000  140845.000000  139563.000000
# mean       7.624853      39.984292      14.001988      18.637576
# std        3.781525      13.588801       8.893337       8.803345
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
np.sum(weather.isnull())
# Out:
# Date                 0
# Location             0
# MinTemp            637
# MaxTemp            322
# Rainfall          1406
# Evaporation      60843
# Sunshine         67816
# WindGustDir       9330
# WindGustSpeed     9270
# WindDir9am       10013
# WindDir3pm        3778
# WindSpeed9am      1348
# WindSpeed3pm      2630
# Humidity9am       1774
# Humidity3pm       3610
# Pressure9am      14014
# Pressure3pm      13981
# Cloud9am         53657
# Cloud3pm         57094
# Temp9am            904
# Temp3pm           2726
# RainToday         1406
# RISK_MM              0
# RainTomorrow         0
# dtype: int64

# %%
weather['MinTemp']=weather['MinTemp'].fillna((weather['MinTemp'].median()))
weather['MaxTemp']=weather['MaxTemp'].fillna((weather['MaxTemp'].median()))
weather['Rainfall']=weather['Rainfall'].fillna((weather['Rainfall'].median()))
weather['Evaporation']=weather['Evaporation'].fillna((weather['Evaporation'].median()))
weather['Sunshine']=weather['Sunshine'].fillna((weather['Sunshine'].median()))
weather['WindGustSpeed']=weather['WindGustSpeed'].fillna((weather['WindGustSpeed'].median()))
weather['WindSpeed9am']=weather['WindSpeed9am'].fillna((weather['WindSpeed9am'].median()))
weather['WindSpeed3pm']=weather['WindSpeed3pm'].fillna((weather['WindSpeed3pm'].median()))
weather['Humidity9am']=weather['Humidity9am'].fillna((weather['Humidity9am'].median()))
weather['Humidity3pm']=weather['Humidity3pm'].fillna((weather['Humidity3pm'].median()))
weather['Pressure9am']=weather['Pressure9am'].fillna((weather['Pressure9am'].median()))
weather['Pressure3pm']=weather['Pressure3pm'].fillna((weather['Pressure3pm'].median()))
weather['Cloud9am']=weather['Cloud9am'].fillna((weather['Cloud9am'].median()))
weather['Cloud3pm']=weather['Cloud3pm'].fillna((weather['Cloud3pm'].median()))
weather['Temp9am']=weather['Temp9am'].fillna((weather['Temp9am'].median()))
weather['Temp3pm']=weather['Temp3pm'].fillna((weather['Temp3pm'].median()))
np.sum(weather.isnull())
# Out:
# Date                 0
# Location             0
# MinTemp              0
# MaxTemp              0
# Rainfall             0
# Evaporation          0
# Sunshine             0
# WindGustDir       9330
# WindGustSpeed        0
# WindDir9am       10013
# WindDir3pm        3778
# WindSpeed9am         0
# WindSpeed3pm         0
# Humidity9am          0
# Humidity3pm          0
# Pressure9am          0
# Pressure3pm          0
# Cloud9am             0
# Cloud3pm             0
# Temp9am              0
# Temp3pm              0
# RainToday         1406
# RISK_MM              0
# RainTomorrow         0
# dtype: int64

# %%
((weather['WindGustDir'].mode()))
# Out:
# 0    W
# dtype: object

# %%
((weather['WindDir9am'].mode()))
# Out:
# 0    N
# dtype: object

# %%
((weather['WindDir3pm'].mode()))
# Out:
# 0    SE
# dtype: object

# %%
((weather['RainToday'].mode()))
# Out:
# 0    No
# dtype: object

# %%
from scipy.stats import mode

# %%
weather['WindGustDir']=weather['WindGustDir'].fillna(weather['WindGustDir']).dropna().mode()[0]
weather['WindDir9am']=weather['WindDir9am'].fillna(weather['WindDir9am']).dropna().mode()[0]
weather['WindDir3pm']=weather['WindDir3pm'].fillna(weather['WindDir3pm']).dropna().mode()[0]
weather['RainToday']=weather['RainToday'].fillna(weather['RainToday']).dropna().mode()[0]
weather.isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RISK_MM          0
# RainTomorrow     0
# dtype: int64

# %%
# mengatasi outlier
from scipy import stats

# %%
weather1=weather.drop(['WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday'], 1)
z = np.abs(stats.zscore(weather1._get_numeric_data()))
print(z)
# Out:
# [[0.1900848  0.0457642  0.20492006 ... 0.0132383  0.01804963 0.27844993]
#  [0.74904204 0.2636769  0.27612488 ... 0.0331139  0.38188612 0.27844993]
#  [0.11182423 0.34806993 0.27612488 ... 0.62024188 0.22179807 0.27844993]
#  ...
#  [1.34382237 0.29180791 0.27612488 ... 0.94028247 0.41099304 0.27844993]
#  [1.06208432 0.51685599 0.27612488 ... 0.69307069 0.64384839 0.27844993]
#  [0.68643359 0.5309215  0.27612488 ... 0.29135155 0.62929493 0.27844993]]

# %%
weather = weather[(z < 3).all(axis=1)]
print(weather.shape)
# Out:
# (131648, 24)

# %%
# dari hasil cleaning data missing value dan outlier didapatkan data bersih sebanyak 131648 data pengamatan dan 24 kolom variabel
