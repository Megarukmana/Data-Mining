# %% [markdown]
# # praktikum 1

# %%
# List

# %%
fruits = [] # empty list

# %%
fruits = ["apple", "banana", "mango"] # list with 3 elements

# %%
another_list = ["this is string", 10] # lis  with different types

# %%
print(fruits)
# Out:
# ['apple', 'banana', 'mango']

# %%
print(another_list)
# Out:
# ['this is string', 10]

# %%
combined = [fruits, another_list]
print(combined)
# Out:
# [['apple', 'banana', 'mango'], ['this is string', 10]]

# %%
gabung = fruits + another_list
print(gabung)
# Out:
# ['apple', 'banana', 'mango', 'this is string', 10]

# %%
# Add element to list 
fruits = ["apple", "banana", "mango"]
fruits.append("orange")
print (fruits)

# atau
fruits = fruits + ["durian"]
print (fruits)
# Out:
# ['apple', 'banana', 'mango', 'orange']
# ['apple', 'banana', 'mango', 'orange', 'durian']

# %%
# Tuple
coordinate = (0, 5)
colors = ("red", "pink", "white")
print(coordinate)
print(colors)
print(coordinate, colors)
# Out:
# (0, 5)
# ('red', 'pink', 'white')
# (0, 5) ('red', 'pink', 'white')

# %%
# perbedaan list dengan tuple
# 1. list dapat ditambahkan isinya tetapi tuple tidak
# 2. list bisa gabungan type datanya :string, numerik dll , kalau tuple tidak
# 3. list pakai kurung siku, tuple siku biasa

# %% [markdown]
# # Data integration

# %%
import pandas as pd
import numpy as np

# %%
## Merging
left = pd.DataFrame ({'key':['K0', 'K1','K2', 'K3'],
                    'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3']})

right = pd.DataFrame ({'key':['K0', 'K1','K2', 'K3'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']})
result1 = pd.merge(left, right, on='key')

# %%
result1
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
print(result1)
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
## Multiple key
left = pd.DataFrame ({'key1':['K0', 'K0', 'K1','K2'],
                      'key2':['K0', 'K1', 'K0','K1'],
                    'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3']})

right = pd.DataFrame ({'key1':['K0', 'K1', 'K1','K2'],
                      'key2':['K0', 'K0', 'K0','K0'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']})
result2 = pd.merge(left, right, on=['key1', 'key2'])
result2
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %%
## Multiple key
left = pd.DataFrame ({'key1':['K0', 'K0', 'K1','K2'],
                      'key2':['K0', 'K1', 'K0','K1'],
                    'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3']})

right = pd.DataFrame ({'key1':['K0', 'K1', 'K1','K2'],
                      'key2':['K0', 'K0', 'K0','K1'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']})
result3 = pd.merge(left, right, on=['key1', 'key2'])
result3
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2
# 3   K2   K1  A3  B3  C3  D3

# %%
## Multiple key
df1 = pd.DataFrame ({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'], 
                     'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']})

df2 = pd.DataFrame ({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7'], 
                     'C': ['C4', 'C5', 'C6', 'C7'],
                    'D': ['D4', 'D5', 'D6', 'D7']})
df3 = pd.DataFrame ({'A': ['A8', 'A9', 'A10', 'A11'],
                    'B': ['B8', 'B9', 'B10', 'B11'], 
                     'C': ['C8', 'C9', 'C10', 'C11'],
                    'D': ['D8', 'D9', 'D10', 'D11']})
                   
result4 = pd.concat([df1, df2, df3])
result4
# Out:
#      A    B    C    D
# 0   A0   B0   C0   D0
# 1   A1   B1   C1   D1
# 2   A2   B2   C2   D2
# 3   A3   B3   C3   D3
# 0   A4   B4   C4   D4
# 1   A5   B5   C5   D5
# 2   A6   B6   C6   D6
# 3   A7   B7   C7   D7
# 0   A8   B8   C8   D8
# 1   A9   B9   C9   D9
# 2  A10  B10  C10  D10
# 3  A11  B11  C11  D11

# %%
# selain pakai key bisa pake concat

# %%
# export data
# contoh : movie.to_csv("hasil_movie.csv")

# %%
# marging
data1 = pd.read_csv("D:\statistika\SEMESTER 6\DATMIN\data1.csv", sep=";")
data2 = pd.read_csv("D:\statistika\SEMESTER 6\DATMIN\data2.csv", sep=";")

data_complete = pd.merge(data1, data2, on ='Nama')
data_complete
# Out:
#   Nama  IPK1  IPK2 Gender  nilai 1  nilai 2
# 0    A     3     2      M        2       40
# 1    B     2     3      M        4       32
# 2    C     3     3      F        6       25
# 3    D     3     2      F        7       24
# 4    E     2     3      F        9       31
# 5    F     2     2      M        4       36
# 6    G     3     3      F        2       42
# 7    H     2     3      M        5       28
# 8    I     3     2      M        4       21
# 9    J     3     2      F        5       20

# %%
data1
# Out:
#   Nama  IPK1  IPK2 Gender
# 0    A     3     2      M
# 1    B     2     3      M
# 2    C     3     3      F
# 3    D     3     2      F
# 4    E     2     3      F
# 5    F     2     2      M
# 6    G     3     3      F
# 7    H     2     3      M
# 8    I     3     2      M
# 9    J     3     2      F

# %%
data2
# Out:
#   Nama  nilai 1  nilai 2
# 0    A        2       40
# 1    B        4       32
# 2    C        6       25
# 3    D        7       24
# 4    E        9       31
# 5    F        4       36
# 6    G        2       42
# 7    H        5       28
# 8    I        4       21
# 9    J        5       20

# %%
# marging
data1 = pd.read_csv("D:\statistika\SEMESTER 6\DATMIN\data1.csv", sep=";")
data2 = pd.read_csv("D:\statistika\SEMESTER 6\DATMIN\data2.csv", sep=";")

data_complete = pd.merge(data1, data2, on ='Nama')
data_complete.head()
# Out:
#   Nama  IPK1  IPK2 Gender  nilai 1  nilai 2
# 0    A     3     2      M        2       40
# 1    B     2     3      M        4       32
# 2    C     3     3      F        6       25
# 3    D     3     2      F        7       24
# 4    E     2     3      F        9       31

# %%
# marging
data1 = pd.read_csv("D:\statistika\SEMESTER 6\DATMIN\data1.csv", sep=";")
data2 = pd.read_csv("D:\statistika\SEMESTER 6\DATMIN\data2.csv", sep=";")

data_complete = pd.merge(data1, data2, on ='Nama')
data_complete.tail()
# Out:
#   Nama  IPK1  IPK2 Gender  nilai 1  nilai 2
# 5    F     2     2      M        4       36
# 6    G     3     3      F        2       42
# 7    H     2     3      M        5       28
# 8    I     3     2      M        4       21
# 9    J     3     2      F        5       20
