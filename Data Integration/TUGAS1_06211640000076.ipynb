# %% [markdown]
# # TUGAS 1

# %% [markdown]
# # Data Integration

# %% [markdown]
# ## Data jumlah ternak sapi yang dipotong di rumah potong hewan menurut provinsi tahun 2008-2017 yang didapat dari Badan Pusat Statistik (BPS)

# %%
import pandas as pd 
import numpy as np

# %%
data1 = pd.read_csv("D:\statistika\SEMESTER 6\DATMIN\Tugas 1 Data Integration\hasil1.csv", sep=";")
data2 = pd.read_csv("D:\statistika\SEMESTER 6\DATMIN\Tugas 1 Data Integration\hasil2.csv", sep=";")
data3 = pd.read_csv("D:\statistika\SEMESTER 6\DATMIN\Tugas 1 Data Integration\hasil3.csv", sep=";")
data4 = pd.read_csv("D:\statistika\SEMESTER 6\DATMIN\Tugas 1 Data Integration\hasil4.csv", sep=";")
data5 = pd.read_csv("D:\statistika\SEMESTER 6\DATMIN\Tugas 1 Data Integration\hasil5.csv", sep=";")

# %%
data1
# Out:
#                 Provinsi     2008     2009
# 0                   ACEH    26239    35601
# 1         SUMATERA UTARA    19676    28901
# 2         SUMATERA BARAT    31533    36512
# 3                   RIAU    18089    19002
# 4                  JAMBI     4625    13803
# 5       SUMATERA SELATAN    25738    32532
# 6               BENGKULU     4146     6327
# 7                LAMPUNG     6856     7644
# 8   KEP. BANGKA BELITUNG     4776     5590
# 9              KEP. RIAU        0        0
# 10           DKI JAKARTA    68906    54091
# 11            JAWA BARAT   133378   163851
# 12           JAWA TENGAH   173914   175552
# 13         DI YOGYAKARTA    21917    18368
# 14            JAWA TIMUR   316471   338091
# 15                BANTEN    55514    86913
# 16                  BALI    36596    37535
# 17   NUSA TENGGARA BARAT    19468    25019
# 18   NUSA TENGGARA TIMUR    17971    26591
# 19      KALIMANTAN BARAT    15100    14597
# 20     KALIMANTAN TENGAH    12955    10901
# ...

# %%
data2
# Out:
#                 Provinsi     2010     2011
# 0                   ACEH    36014    36287
# 1         SUMATERA UTARA    31926    32163
# 2         SUMATERA BARAT    37328    38056
# 3                   RIAU    19645    21895
# 4                  JAMBI    17101    17484
# 5       SUMATERA SELATAN    33985    34390
# 6               BENGKULU     6473     7213
# 7                LAMPUNG     9596     9775
# 8   KEP. BANGKA BELITUNG     7697     8577
# 9              KEP. RIAU        0        0
# 10           DKI JAKARTA    55565    56917
# 11            JAWA BARAT   165877   220150
# 12           JAWA TENGAH   176543   185371
# 13         DI YOGYAKARTA    19834    24941
# 14            JAWA TIMUR   340476   411249
# 15                BANTEN    90652    91578
# 16                  BALI    38326    62763
# 17   NUSA TENGGARA BARAT    29059    31412
# 18   NUSA TENGGARA TIMUR    27710    30883
# 19      KALIMANTAN BARAT    14767    29501
# 20     KALIMANTAN TENGAH    10936    11209
# ...

# %%
data3
# Out:
#                 Provinsi     2012     2013
# 0                   ACEH    30145    11316
# 1         SUMATERA UTARA    21761    24434
# 2         SUMATERA BARAT    45965    33436
# 3                   RIAU    10824    19921
# 4                  JAMBI     9095     7759
# 5       SUMATERA SELATAN    31480    23346
# 6               BENGKULU     7614     6531
# 7                LAMPUNG     8489    14364
# 8   KEP. BANGKA BELITUNG     7982     7794
# 9              KEP. RIAU        0      900
# 10           DKI JAKARTA    17418    15415
# 11            JAWA BARAT   169203   190462
# 12           JAWA TENGAH   256639   175748
# 13         DI YOGYAKARTA    19818    13777
# 14            JAWA TIMUR   362612   405883
# 15                BANTEN    33557    79503
# 16                  BALI    63662    46934
# 17   NUSA TENGGARA BARAT    35026    34197
# 18   NUSA TENGGARA TIMUR    25635    20727
# 19      KALIMANTAN BARAT    28853    13930
# 20     KALIMANTAN TENGAH    15802    13975
# ...

# %%
data4
# Out:
#                 Provinsi     2014     2015
# 0                   ACEH    10986    13231
# 1         SUMATERA UTARA    20797    26250
# 2         SUMATERA BARAT    30868    34005
# 3                   RIAU    15777    15293
# 4                  JAMBI     5254     6960
# 5       SUMATERA SELATAN    16070    19059
# 6               BENGKULU     7508     7075
# 7                LAMPUNG    13077    18537
# 8   KEP. BANGKA BELITUNG     8062     7789
# 9              KEP. RIAU      828      944
# 10           DKI JAKARTA    26502    39070
# 11            JAWA BARAT   160488   186405
# 12           JAWA TENGAH   157180   151350
# 13         DI YOGYAKARTA    12391    12146
# 14            JAWA TIMUR   237677   261999
# 15                BANTEN    84231   107376
# 16                  BALI    40708    42921
# 17   NUSA TENGGARA BARAT    35005    37482
# 18   NUSA TENGGARA TIMUR    26012    31891
# 19      KALIMANTAN BARAT    10985    10831
# 20     KALIMANTAN TENGAH    13323    12193
# ...

# %%
data5
# Out:
#                 Provinsi     2016     2017
# 0                   ACEH    13708    12246
# 1         SUMATERA UTARA    23770    24541
# 2         SUMATERA BARAT    35362    27902
# 3                   RIAU    18917    23822
# 4                  JAMBI     4069     6611
# 5       SUMATERA SELATAN    14084    16617
# 6               BENGKULU     7707     7284
# 7                LAMPUNG    19929    21284
# 8   KEP. BANGKA BELITUNG     7930     8786
# 9              KEP. RIAU      834      799
# 10           DKI JAKARTA    38227    32405
# 11            JAWA BARAT   185937   171586
# 12           JAWA TENGAH   131333   111737
# 13         DI YOGYAKARTA    12217    12962
# 14            JAWA TIMUR   240059   251177
# 15                BANTEN   104209    88723
# 16                  BALI    33492    32102
# 17   NUSA TENGGARA BARAT    39587    40247
# 18   NUSA TENGGARA TIMUR    30499    28975
# 19      KALIMANTAN BARAT    14775    16593
# 20     KALIMANTAN TENGAH    10288    11704
# ...

# %%
data_completed1 = pd.merge(data1, data2, on='Provinsi')
data_completed2 = pd.merge(data3, data4, on='Provinsi')
data_completed3 = pd.merge(data_completed1, data_completed2, on='Provinsi')
data_completed4 = pd.merge(data_completed3, data5, on='Provinsi')
data_completed4
# Out:
#                 Provinsi     2008     2009     2010     2011     2012  \
# 0                   ACEH    26239    35601    36014    36287    30145
# 1         SUMATERA UTARA    19676    28901    31926    32163    21761
# 2         SUMATERA BARAT    31533    36512    37328    38056    45965
# 3                   RIAU    18089    19002    19645    21895    10824
# 4                  JAMBI     4625    13803    17101    17484     9095
# 5       SUMATERA SELATAN    25738    32532    33985    34390    31480
# 6               BENGKULU     4146     6327     6473     7213     7614
# 7                LAMPUNG     6856     7644     9596     9775     8489
# 8   KEP. BANGKA BELITUNG     4776     5590     7697     8577     7982
# 9              KEP. RIAU        0        0        0        0        0
# 10           DKI JAKARTA    68906    54091    55565    56917    17418
# 11            JAWA BARAT   133378   163851   165877   220150   169203
# ...
